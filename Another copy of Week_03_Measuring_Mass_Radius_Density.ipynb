# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.io.ascii
# %matplotlib inline

# %%
# !pip install radvel
# !pip install pylightcurve
# Out:
# Requirement already satisfied: radvel in /usr/local/lib/python3.11/dist-packages (1.4.11)
# Requirement already satisfied: cython>=0.23 in /usr/local/lib/python3.11/dist-packages (from radvel) (3.0.12)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.11/dist-packages (from radvel) (1.24.3)
# Requirement already satisfied: scipy==1.10.1 in /usr/local/lib/python3.11/dist-packages (from radvel) (1.10.1)
# Requirement already satisfied: matplotlib>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from radvel) (3.10.0)
# Requirement already satisfied: corner>=2.0 in /usr/local/lib/python3.11/dist-packages (from radvel) (2.2.3)
# Requirement already satisfied: astropy>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from radvel) (7.0.1)
# Requirement already satisfied: emcee>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from radvel) (3.1.6)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from radvel) (2.2.2)
# Requirement already satisfied: nbsphinx==0.9.3 in /usr/local/lib/python3.11/dist-packages (from radvel) (0.9.3)
# Requirement already satisfied: jupyter_client>=5.2.4 in /usr/local/lib/python3.11/dist-packages (from radvel) (6.1.12)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from radvel) (6.17.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from radvel) (3.1.5)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from radvel) (2.8.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from radvel) (0.3.9)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from radvel) (7.34.0)
# Requirement already satisfied: coveralls==3.2.0 in /usr/local/lib/python3.11/dist-packages (from radvel) (3.2.0)
# Requirement already satisfied: coverage<6.0,>=4.1 in /usr/local/lib/python3.11/dist-packages (from coveralls==3.2.0->radvel) (5.5)
# Requirement already satisfied: docopt>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from coveralls==3.2.0->radvel) (0.6.2)
# Requirement already satisfied: requests>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from coveralls==3.2.0->radvel) (2.32.3)
# Requirement already satisfied: docutils in /usr/local/lib/python3.11/dist-packages (from nbsphinx==0.9.3->radvel) (0.21.2)
# Requirement already satisfied: nbconvert!=5.4 in /usr/local/lib/python3.11/dist-packages (from nbsphinx==0.9.3->radvel) (7.16.6)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.11/dist-packages (from nbsphinx==0.9.3->radvel) (5.7.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from nbsphinx==0.9.3->radvel) (5.10.4)
# Requirement already satisfied: sphinx>=1.8 in /usr/local/lib/python3.11/dist-packages (from nbsphinx==0.9.3->radvel) (8.1.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.11/dist-packages (from astropy>=1.1.2->radvel) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in /usr/local/lib/python3.11/dist-packages (from astropy>=1.1.2->radvel) (0.2025.2.10.0.33.26)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=1.1.2->radvel) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=1.1.2->radvel) (24.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->radvel) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->radvel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->radvel) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->radvel) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->radvel) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->radvel) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->radvel) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->radvel) (3.0.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter_client>=5.2.4->radvel) (5.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.3->radvel) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.3->radvel) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.3->radvel) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.3->radvel) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.3->radvel) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.3->radvel) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.20.0->radvel) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.20.0->radvel) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.0->radvel) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->radvel) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter_client>=5.2.4->radvel) (4.3.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4->nbsphinx==0.9.3->radvel) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert!=5.4->nbsphinx==0.9.3->radvel) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4->nbsphinx==0.9.3->radvel) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4->nbsphinx==0.9.3->radvel) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4->nbsphinx==0.9.3->radvel) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4->nbsphinx==0.9.3->radvel) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert!=5.4->nbsphinx==0.9.3->radvel) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->nbsphinx==0.9.3->radvel) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->nbsphinx==0.9.3->radvel) (4.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->radvel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->radvel) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=1.0.0->coveralls==3.2.0->radvel) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=1.0.0->coveralls==3.2.0->radvel) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=1.0.0->coveralls==3.2.0->radvel) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=1.0.0->coveralls==3.2.0->radvel) (2025.1.31)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=1.8->nbsphinx==0.9.3->radvel) (1.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert!=5.4->nbsphinx==0.9.3->radvel) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert!=5.4->nbsphinx==0.9.3->radvel) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx==0.9.3->radvel) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx==0.9.3->radvel) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx==0.9.3->radvel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx==0.9.3->radvel) (0.22.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert!=5.4->nbsphinx==0.9.3->radvel) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert!=5.4->nbsphinx==0.9.3->radvel) (4.12.2)
# Requirement already satisfied: pylightcurve in /usr/local/lib/python3.11/dist-packages (4.0.4)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.11/dist-packages (from pylightcurve) (3.10.0)
# Requirement already satisfied: numpy>=1.19.2 in /usr/local/lib/python3.11/dist-packages (from pylightcurve) (1.24.3)
# Requirement already satisfied: emcee>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from pylightcurve) (3.1.6)
# Requirement already satisfied: astropy>=4.2 in /usr/local/lib/python3.11/dist-packages (from pylightcurve) (7.0.1)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.11/dist-packages (from pylightcurve) (1.10.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pylightcurve) (6.0.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.11/dist-packages (from astropy>=4.2->pylightcurve) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in /usr/local/lib/python3.11/dist-packages (from astropy>=4.2->pylightcurve) (0.2025.2.10.0.33.26)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=4.2->pylightcurve) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.3->pylightcurve) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.3->pylightcurve) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.3->pylightcurve) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.3->pylightcurve) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.3->pylightcurve) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.3->pylightcurve) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.3->pylightcurve) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->pylightcurve) (1.17.0)

# %%
#give colab access to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read in RV data for HD 189733 b

# %%
rv_data = astropy.io.ascii.read("/content/drive/My Drive/Colab Notebooks/UID_0098505_RVC_002.tbl.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-09c2964e199f> in <cell line: 0>()
# ----> 1 rv_data = astropy.io.ascii.read("/content/drive/My Drive/Colab Notebooks/UID_0098505_RVC_002.tbl.txt")
#
# /usr/local/lib/python3.11/dist-packages/astropy/io/ascii/ui.py in read(table, guess, **kwargs)
#     435         # through below to the non-guess way so that any problems result in a
#     436         # more useful traceback.
# --> 437         dat = _guess(table, new_kwargs, format, fast_reader)
#     438         if dat is None:
#     439             guess = False
#
# /usr/local/lib/python3.11/dist-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     680                 reader.read(table_guess_subset)
#     681
# --> 682             dat = reader.read(table)
#     683             _read_trace.append(
#     684                 {
#
# /usr/local/lib/python3.11/dist-packages/astropy/io/ascii/core.py in read(self, table)
#    1422
#    1423         # Get a list of the lines (rows) in the table
# -> 1424         self.lines = self.inputter.get_lines(table, newline=newline)
#    1425
#    1426         # Set self.data.data_lines to a slice of lines contain the data rows
#
# /usr/local/lib/python3.11/dist-packages/astropy/io/ascii/core.py in get_lines(self, table, newline)
#     334                 or ("\n" not in table + "" and "\r" not in table + "")
#     335             ):
# --> 336                 with get_readable_fileobj(table, encoding=self.encoding) as fileobj:
#     337                     table = fileobj.read()
#     338             if newline is None:
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers, use_fsspec, fsspec_kwargs, close_files)
#     363                     http_headers=http_headers,
#     364                 )
# --> 365             fileobj = io.FileIO(name_or_obj, "r")
#     366             if is_url and not cache:
#     367                 delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/UID_0098505_RVC_002.tbl.txt'

# %%
rv_data

# %% [markdown]
# ## Plot the best-fit model

# %%
t = rv_data["JD"].data
if False:
    import JW_lib
    orbital_solution = [2.21857567, 2457929.288, 0.028, 136.42, 205.0]
    rv = JW_lib.RadialVelocity(orbital_solution)
    # The parameters are period, time at periastron, eccentricity, argument of periastron, RV semi-amplitude

    # Calculate model RVs
    rvs = rv.rv_drive(t)
else:
    import radvel
    orbital_solution = [2.21857567, 2457929.288, 0.028, 136.42 / 360.0 * 2 * np.pi, 205.0]
    rvs = radvel.kepler.rv_drive(t, orbital_solution, use_c_kepler_solver=False)

per = 2.21857567

# %matplotlib inline
# Fold data and plot model against data
ind = np.argsort(t % per)
plt.errorbar(rv_data["JD"] % per, rv_data["Radial_Velocity"], rv_data["Radial_Velocity_Uncertainty"],
             color="black", ms=5, marker="o", ls="none", label="Data")
plt.plot((t % per)[ind], rvs[ind], "r-", label="Model", lw=3)
plt.legend()
plt.xlabel("Time [day]")
plt.ylabel("RV [m/s]")
plt.tight_layout()

# %% [markdown]
# ## Read in transit data for HD 189733 b

# %%
tr_data = astropy.io.ascii.read("/content/drive/My Drive/Colab Notebooks/UID_0098505_PLC_025.tbl.txt")
# tr_data = astropy.io.ascii.read("/Users/wang.12220/Downloads/UID_0013192_PLC_010.tbl.txt")
# tr_data = astropy.io.ascii.read("/Users/wang.12220/Downloads/1315925044.txt")

# %%
tr_data

# %%
# prompt: find the largest value in the column relative_flux in tr_data

import numpy as np

# Assuming 'tr_data' is already loaded as in the provided code.
# If not, uncomment the following line to load it again:
# tr_data = astropy.io.ascii.read("/content/drive/My Drive/Colab Notebooks/UID_0098505_PLC_025.tbl.txt")

if 'Relative_Flux' in tr_data.colnames:
    largest_relative_flux = np.max(tr_data['Relative_Flux'])
    print(f"The largest value in the 'relative_flux' column is: {largest_relative_flux}")
else:
    print("The column 'relative_flux' does not exist in the data.")

# %%
average = tr_data['Relative_Flux'].mean()
print(average)
print()

baseline = tr_data['Relative_Flux'][0:300].mean()
print(baseline)
print()

sdev = tr_data['Relative_Flux'].std()
print(standarddev)

# Modified Z-Score normalization formula

def normal(data, base):
  return data / base

# %%
# Calculate the normalized flux and normalized flux uncertainty
tr_data['Normalized_Flux'] = normal(tr_data['Relative_Flux'], baseline)
tr_data

# %%
average = tr_data['Normalized_Flux'].mean()
average

# %% [markdown]
# ## Calculate the best-fit model

# %%
import pylightcurve as plc

# best-fit parameters from ExoFast
#planet, stellar_logg, stellar_temperature, stellar_metallicity, rp_over_rs, \
#fp_over_fs, period, sma_over_rs, eccentricity, inclination, periastron, mid_time = \
#"HD 189733 b", 4.192, 6040.0, 0.19, 0.074451, 2.4367028655531474e-07, \
#21.218473, 23.428833, 0.68, 87.07, 121.36, 2454438.483466

#planet = plc.get_planet('hd189733b')   ## Use this to get all the data for the star without manually entring everything


#time_array = tr_data["HJD"].data
# time_array = tr_data["col1"].data

# Calculate Limb-darkening parameters
#limb_darkening_coefficients = plc.clablimb('claret', stellar_logg, stellar_temperature, stellar_metallicity, 'V')


# Calculate transiting light curve
#flux_array = plc.transit_integrated('claret', limb_darkening_coefficients, rp_over_rs, period, sma_over_rs,
#                                        eccentricity, inclination, periastron, mid_time, time_array, 120, 120,
#                                        precision=6)

# If the above report errors, comment out the above lines, try change False to True, and run the following:
if True:
    planet = plc.get_planet('hd189733b')   ## Use this to get all the data for the star without manually entring everything

    time_array = tr_data["HJD"].data
    #time_array = tr_data["col1"].data

    # Calculate Limb-darkening parameters
    limb_darkening_coefficients = planet.filter('sdss_r').limb_darkening_coefficients  ## New way to gt the coeffs

    flux_array = planet.transit_integrated(time_array, time_format='HJD_TDB',
                                           exp_time=120, time_stamp = 'mid', filter_name='sdss_r', max_sub_exp_time=1)

# %% [markdown]
# ## Plot the best-fit model

# %%
tr_data.colnames

# %%
plt.errorbar(tr_data["HJD"], tr_data["Normalized_Flux"], tr_data["Relative_Flux_Uncertainty"], ms=5, \
             marker="o", ls="none", label="Data", color="black", alpha=0.3)

# flx = 2.512**(-tr_data["col2"])
# flx = flx / np.median(flx)
# plt.plot(tr_data["col1"], flx , ms=5, \
#              marker="o", ls="none", label="Data", color="black", alpha=0.3)

plt.plot(time_array, flux_array, 'r-', lw=3, label="Model")
plt.ylim(plt.ylim()[0], plt.ylim()[1])
plt.xlabel('Time [day]')
plt.ylabel('Normalized Flux')
plt.legend()
plt.tight_layout()

# %%
# (planet, stellar_logg, stellar_temperature, stellar_metallicity, rp_over_rs, fp_over_fs,
#      period, sma_over_rs, eccentricity, inclination, periastron, mid_time) = plc.find_oec_parameters('hd17156b')

# %% [markdown]
# ## Fitting RV data for HD 189733 b

# %%
import scipy.signal as signal
x = rv_data["JD"]
y = rv_data["Radial_Velocity"]
e = rv_data["Radial_Velocity_Uncertainty"]

# %% [markdown]
# ## Finding the periodicity in the data

# %%
nout = 1e5
f = np.linspace(0.01, 10.0, int(nout)) # frequency (1/day) at which power is calculated.
#pgram = signal.lombscargle(x, y, f, normalize=True)
pgram = signal.lombscargle(x, y, f)

# %%
plt.subplot(2, 1, 1)
plt.errorbar(x, y , e, ms=5, marker="o", ls="none", color="black")
plt.xlabel("Time [JD]")
plt.ylabel("RV [m/s]")
plt.subplot(2, 1, 2)
plt.plot(2 * np.pi / f, pgram, color="black")
plt.xscale("log")
plt.xlabel("Period [day]")
plt.ylabel("Power")

# %%
print("The period with the highest power is: ", 2 * np.pi / f[np.where(pgram == np.max(pgram))][0], " day")

# %% [markdown]
# ## Now gather information for orbital solution from references, we are ready for MCMC, which gives uncertainties for best-fit parameters.

# %% [markdown]
# ## Define a model function with five parameters:
#
# ## period (day), time at periastron (MJD), eccentricity, argument of periastron (degree), RV amplitude (m/s)

# %%
# def calcModel(params, t_stamp=None):
#     per, t0, ecc, omega, rv_amp = params["per"], params["t0"], params["ecc"], params["omega"], params["K"]
#     rv = JW_lib.RadialVelocity([per, t0, ecc, omega, rv_amp])
#     return(rv.rv_drive(t_stamp))

def calcModel(params, t_stamp=None):
    per, t0, ecc, omega, rv_amp = params["per"], params["t0"], params["ecc"], params["omega"], params["K"]
    return(radvel.kepler.rv_drive(t_stamp, [per, t0, ecc, omega, rv_amp], use_c_kepler_solver=False))

# %% [markdown]
# ## Define prior function

# %%
def b_range(x, b):
    if x > b:
        return -np.inf
    else:
        return 0.

def a_b_range(x, a, b):
    if x < a:
        return -np.inf
    elif x > b:
        return -np.inf
    else:
        return 0.

def log_gaussian_prior(x, x0, std):
    return((-(x - x0)**2 / (2 * (std)**2)) / 2.3)




# define data and params that are fixed and variable
#planet_name = "HD 17156 b"
planet_name = "HD 189773 b"

if planet_name == "Teegarden b":
    log_priors = {}
    log_priors['per']           = lambda x: a_b_range(x, 4.8, 5.0)
    log_priors['t0']           = lambda x: a_b_range(x, 2458090.603207, 2458092.603207)
    log_priors['ecc']           = lambda x: a_b_range(x, 0., 0.95)
    log_priors['omega']       = lambda x: a_b_range(x, 0., 2*np.pi)
    log_priors['K']           = lambda x: a_b_range(x, 1., 5.)
    t_stamp      = rv_tg["col1"]
    data         = rv_tg["col2"]
    data_errors  = rv_tg["col3"]

    params = [4.910122, 2458091.603207, 0.222619, 82.339257 / 360 * 2 * np.pi,2.156248]
    params_keys = ["per", "t0", "ecc", "omega", "K"]
    params_fixed = []
    params_fixed_keys = []
elif planet_name == "HD 189773 b":
    log_priors = {}
    log_priors['per']           = lambda x: a_b_range(x, 2., 24)
    log_priors['t0']           = lambda x: a_b_range(x, 2457927.288, 2457931.288)
    log_priors['ecc']           = lambda x: a_b_range(x, 0., 0.95)
    log_priors['omega']       = lambda x: a_b_range(x, 0., 360.)
    log_priors['K']           = lambda x: a_b_range(x, 100., 500.)
    t_stamp      = rv_data["JD"]
    data         = rv_data["Radial_Velocity"]
    data_errors  = rv_data["Radial_Velocity_Uncertainty"]

    params = [2.21857567, 2457929.288, 0.028, 136.42 / 360.0 * 2 * np.pi, 205.0]
    params_keys = ["per", "t0", "ecc", "omega", "K"]
    params_fixed = []
    params_fixed_keys = []
else:
    print(""" Give me either "HD 189733 b" or "Teegarden b" """)

# %% [markdown]
# ## Define likelihood function

# %%
def calc_log_prob(params, data, data_errors, params_keys=params_keys, params_fixed=params_fixed, \
                  params_fixed_keys=params_fixed_keys, t_stamp=t_stamp, plot_flag=False):
    # Make dictionary
    params_dic = {}
    for i, key in enumerate(params_keys):
        params_dic[key]       = params[i]

    for i, key in enumerate(params_fixed_keys):
        params_dic[key]       = params_fixed[i]

    # Prior calculation of all input parameters
    log_prior = 0.

    for key in params_keys:
        if not(type(params_dic[key]) is list):
            log_prior += log_priors[key](params_dic[key])
        else:
            for val in params_dic[key]:
                log_prior += log_priors[key](val)

    # Return -inf if parameters fall outside prior distribution
    if (log_prior == -np.inf):
        return -np.inf

    # Calculate the log-likelihood
    log_likelihood = 0.

    # Calculate the forward model, this
    # returns the wavelengths in um and flux in W/m2

    rv_model = calcModel(params_dic, t_stamp=t_stamp)

    if plot_flag:
        plt.plot(t_stamp, rv_model, "k^-", alpha=0.5, label="model")
        plt.plot(t_stamp, data, "rx-", alpha=0.5, label="data")
        plt.xlabel("Time [BJD]")
        plt.ylabel("RV [m/s]")
        plt.legend()
        plt.show()

    # Just to make sure that a long chain does not die
    # unexpectedly:
    # Return -inf if forward model returns NaN values
    if np.sum(np.isnan(rv_model)) > 0:
        print("NaN spectrum encountered")
        return -np.inf

    # Calculate log-likelihood
    log_likelihood += -np.sum(((rv_model - data)/ \
                       data_errors)**2.)/2.

    if np.isnan(log_prior + log_likelihood):
        return -np.inf
    else:
        return log_prior + log_likelihood

# %% [markdown]
# ## Test: calculate likelihood function

# %%
print(calc_log_prob(params, data, data_errors, plot_flag=True))

# %% [markdown]
# ## Now MCMC

# %%
import emcee

# %%
per = params[0]; e_per = 0.01
t0 = params[1]; e_t0 = 0.05
ecc = params[2]; e_ecc = 0.01
omega = params[3]; e_omega = 0.1
K = params[4]; e_K = 0.1


p_0 = params
e_p = [e_per, e_t0, e_ecc, e_omega, e_K]


ndim, nwalkers, nruns = len(p_0), 200, 1000
pos = [p_0 + e_p*np.random.randn(ndim) for i in range(nwalkers)]

import time as timer
start = timer.time()

from multiprocessing import Pool

# if pool works then use True, this option will use multi thread to increase computaional speed. Otherwise use False.
if False:
    with Pool() as pool:

        # Initialize the sampler
        sampler = emcee.EnsembleSampler(nwalkers, ndim, calc_log_prob,
                                       args=(data, data_errors), pool=pool, threads=5)
        sampler.run_mcmc(pos, 3000)


        #End timer
        end = timer.time()
        serial_time = end - start
        print("MCMC took {0:.1f} seconds".format(serial_time))
else:
        # Initialize the sampler
        sampler = emcee.EnsembleSampler(nwalkers, ndim, calc_log_prob,
                                       args=(data, data_errors))
        sampler.run_mcmc(pos, 3000)


        #End timer
        end = timer.time()
        serial_time = end - start
        print("MCMC took {0:.1f} seconds".format(serial_time))

# %% [markdown]
# ## Check MCMC result

# %%
samples = sampler.chain[:, 1000:, :].reshape((-1, ndim))[0:-1:10, :]


print("flat chain shape: {0}".format(samples.shape))

# %%
import corner
fig = corner.corner(samples, labels=params_keys, plot_contours=True)

# %% [markdown]
# ## Plot models with data

# %%
fig, ax = plt.subplots(2,1)

inds = np.random.randint(len(samples[:,0]), size=100)
for ind in inds:
    # Make dictionary
    params_dic = {}
    for i, key in enumerate(params_keys):
        params_dic[key]       = samples[ind,:][i]
    for i, key in enumerate(params_fixed_keys):
        params_dic[key]       = params_fixed[i]
    #print(params_dic["logg"])
    rv_model = calcModel(params_dic, t_stamp=t_stamp)
    ax[0].plot(t_stamp, rv_model, 'r', alpha=0.05,label='_nolegend_')


ax[0].errorbar(t_stamp, data, data_errors, ms=5, marker="o", alpha=0.2, ls="none", color="black", label="Data")
ax[0].plot(t_stamp, rv_model, "r", alpha=0.5, label="Model")


# Getting median values
values = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                             zip(*np.percentile(samples, [16, 50, 84],
                                                axis=0)))
params = np.array(list(values))[:,0]
params_fixed = []
params_dic = {}
for i, key in enumerate(params_keys):
    params_dic[key]       = params[i]
for i, key in enumerate(params_fixed_keys):
    params_dic[key]       = params_fixed[i]


rv_model = calcModel(params_dic, t_stamp=t_stamp)
per = params_dic["per"]
ind1 = np.argsort(t_stamp % per)
ax[1].errorbar(t_stamp % per, data, data_errors, ms=5, marker="o", alpha=0.2, ls="none", color="black", label="Data")
ax[1].plot((t_stamp % per)[ind1], rv_model[ind1], "r", alpha=0.5,label='Model', lw=3)

ax[1].set_xlabel("Time [HJD]", fontsize=15)
ax[0].set_ylabel("RV [m/s]", fontsize=15)
ax[1].set_ylabel("RV [m/s]", fontsize=15)

plt.gca().tick_params(labelsize=15)
ax[1].legend(fontsize=15)
# plt.tight_layout()
# plt.savefig("model_data.png")

# %%
print(limb_darkening_coefficients)

# %%
cat UID_0098505_RVC_002.tbl.txt

# %%
==
